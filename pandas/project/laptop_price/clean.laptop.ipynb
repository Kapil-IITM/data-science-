# %%
import pandas as pd 
import numpy as np

# %%
total_dataset =pd.read_csv("laptopPrice.csv")

# %%
total_dataset.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
total_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
total_dataset.shape
# Out:
# (823, 19)

# %%
total_dataset.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
total_dataset.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
total_dataset['brand'].value_counts()
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
total_dataset.duplicated().sum()
# Out:
# np.int64(21)

# %%
total_dataset.drop_duplicates(inplace=True)

# %%
total_dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
total_dataset.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df =total_dataset

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
apple=df[df['brand']=="APPLE"]

# %%
apple.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count      23.000000          23.000000          23.000000
# mean   157081.304348         853.652174          84.826087
# std     54370.286948        1875.694747         174.698611
# min     85990.000000           3.000000           1.000000
# 25%    118990.000000          42.000000           5.000000
# 50%    149990.000000         108.000000          13.000000
# 75%    179990.000000         640.000000          70.000000
# max    309990.000000        6725.000000         629.000000

# %%
apple['ram_gb'].unique()
# Out:
# array(['8 GB', '16 GB', '4 GB', '32 GB'], dtype=object)

# %%
apple_8gb =apple[apple['ram_gb']=='8 GB']

# %%
apple_8gb['processor_brand'].unique()
# Out:
# array(['Intel', 'M1'], dtype=object)

# %%
apple_8gb_intel_brand =apple_8gb[apple_8gb['processor_brand']=='Intel']

# %%
apple_8gb_intel_brand
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
#
#         ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 309  512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 310  512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
#
#     msoffice   Price   rating  Number of Ratings  Number of Reviews
# 309       No  159990  4 stars                 32                  5
# 310       No  172090  4 stars                108                 13

# %%
df =df.drop(['weight',"warranty","msoffice","rating","Number of Ratings","Number of Reviews"],axis=1)# drop columns and axis =1 means columns

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb Touchscreen  Price
# 0    0 GB  1024 GB  Windows  64-bit            0 GB          No  34649
# 1    0 GB  1024 GB  Windows  64-bit            0 GB          No  38999
# 2    0 GB  1024 GB  Windows  64-bit            0 GB          No  39999
# 3  512 GB     0 GB  Windows  32-bit            2 GB          No  69990
# 4    0 GB   512 GB  Windows  64-bit            0 GB          No  26990

# %%
df['Touchscreen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
touch_dict ={
  'No':0, 'Yes':1  
}

# %%
df['Touchscreen']=df['Touchscreen'].map(touch_dict)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
proccessor_brand_dict={
    'Intel':0,
    'AMD':1,
    'M1':2
}

# %%
ssd_dict ={
    '0 GB':0,
    '512 GB':512,
    '256 GB':256,
    '128 GB':128,
    '1024 GB':1024,
    '2048 GB':2048,
    '3072 GB':3072
}

# %%
ram_type_dict ={
    'DDR4':0,
    'LPDDR4':1,
    'LPDDR4X':2,
    'DDR5':3,
    'DDR3':4,
    'LPDDR3':5
}

# %%
df['processor_brand']=df['processor_brand'].map(proccessor_brand_dict)

# %%
df.head()
# Out:
#     brand  processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS                0        Core i3            10th   4 GB     DDR4
# 1  Lenovo                0        Core i3            10th   4 GB     DDR4
# 2  Lenovo                0        Core i3            10th   4 GB     DDR4
# 3    ASUS                0        Core i5            10th   8 GB     DDR4
# 4    ASUS                0   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  Touchscreen  Price
# 0    0 GB  1024 GB  Windows  64-bit            0 GB            0  34649
# 1    0 GB  1024 GB  Windows  64-bit            0 GB            0  38999
# 2    0 GB  1024 GB  Windows  64-bit            0 GB            0  39999
# 3  512 GB     0 GB  Windows  32-bit            2 GB            0  69990
# 4    0 GB   512 GB  Windows  64-bit            0 GB            0  26990

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            802 non-null    object
#  1   processor_brand  802 non-null    int64
#  2   processor_name   802 non-null    object
#  3   processor_gnrtn  802 non-null    object
#  4   ram_gb           802 non-null    object
#  5   ram_type         802 non-null    object
#  6   ssd              802 non-null    object
#  7   hdd              802 non-null    object
#  8   os               802 non-null    object
#  9   os_bit           802 non-null    object
#  10  graphic_card_gb  802 non-null    object
#  11  Touchscreen      802 non-null    int64
#  12  Price            802 non-null    int64
# dtypes: int64(3), object(10)
# memory usage: 87.7+ KB

# %%
df['processor_gnrtn'].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
processor_gnrtn_dict = {
    '10th':5, 'Not Available':0, '11th':6, '7th':2, '8th':3, '9th':4, '4th':1,
       '12th':7
}

# %%
df['processor_gnrtn'] = df['processor_gnrtn'].map(processor_gnrtn_dict)

# %%
df.head()
# Out:
#     brand  processor_brand processor_name  processor_gnrtn ram_gb ram_type  \
# 0    ASUS                0        Core i3                5   4 GB     DDR4
# 1  Lenovo                0        Core i3                5   4 GB     DDR4
# 2  Lenovo                0        Core i3                5   4 GB     DDR4
# 3    ASUS                0        Core i5                5   8 GB     DDR4
# 4    ASUS                0   Celeron Dual                0   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  Touchscreen  Price
# 0    0 GB  1024 GB  Windows  64-bit            0 GB            0  34649
# 1    0 GB  1024 GB  Windows  64-bit            0 GB            0  38999
# 2    0 GB  1024 GB  Windows  64-bit            0 GB            0  39999
# 3  512 GB     0 GB  Windows  32-bit            2 GB            0  69990
# 4    0 GB   512 GB  Windows  64-bit            0 GB            0  26990

# %%
df['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
processor_name_dict = {
    'Core i3':1, 'Core i5':2, 'Celeron Dual':3, 'Ryzen 5':4, 'Core i7':5,
       'Core i9':6, 'M1':7, 'Pentium Quad':8, 'Ryzen 3':9, 'Ryzen 7':10, 'Ryzen 9':11

}

# %%
df['processor_name']= df['processor_name'].map(processor_name_dict)

# %%
df.head()
# Out:
#     brand  processor_brand  processor_name  processor_gnrtn ram_gb ram_type  \
# 0    ASUS                0               1                5   4 GB     DDR4
# 1  Lenovo                0               1                5   4 GB     DDR4
# 2  Lenovo                0               1                5   4 GB     DDR4
# 3    ASUS                0               2                5   8 GB     DDR4
# 4    ASUS                0               3                0   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  Touchscreen  Price
# 0    0 GB  1024 GB  Windows  64-bit            0 GB            0  34649
# 1    0 GB  1024 GB  Windows  64-bit            0 GB            0  38999
# 2    0 GB  1024 GB  Windows  64-bit            0 GB            0  39999
# 3  512 GB     0 GB  Windows  32-bit            2 GB            0  69990
# 4    0 GB   512 GB  Windows  64-bit            0 GB            0  26990

# %%
df['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
ram_gb_dict = {
    '4 GB':1, '8 GB':2, '16 GB':3, '32 GB':4
}

# %%
df['ram_gb'] =df['ram_gb'].map(ram_gb_dict)

# %%
df.head()
# Out:
#     brand  processor_brand  processor_name  processor_gnrtn  ram_gb ram_type  \
# 0    ASUS                0               1                5       1     DDR4
# 1  Lenovo                0               1                5       1     DDR4
# 2  Lenovo                0               1                5       1     DDR4
# 3    ASUS                0               2                5       2     DDR4
# 4    ASUS                0               3                0       1     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  Touchscreen  Price
# 0    0 GB  1024 GB  Windows  64-bit            0 GB            0  34649
# 1    0 GB  1024 GB  Windows  64-bit            0 GB            0  38999
# 2    0 GB  1024 GB  Windows  64-bit            0 GB            0  39999
# 3  512 GB     0 GB  Windows  32-bit            2 GB            0  69990
# 4    0 GB   512 GB  Windows  64-bit            0 GB            0  26990

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
brand_dict = {
'ASUS':1, 'Lenovo':2, 'acer':3, 'Avita':4, 'HP':5, 'DELL':6, 'MSI':7, 'APPLE':8
}

# %%
df['brand'] = df['brand'].map(brand_dict)

# %%
df['graphic_card_gb'].unique()
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
graphic_card_gb_dict = {
    '0 GB':1, '2 GB':2, '4 GB':3, '6 GB':4, '8 GB':5
}

# %%
df['graphic_card_gb'] = df['graphic_card_gb'].map(graphic_card_gb_dict)

# %%
df['os_bit'].unique()
# Out:
# array(['64-bit', '32-bit'], dtype=object)

# %%
os_bit_dict = {
    '64-bit':2, '32-bit':1
}

# %%
df['os_bit']=df['os_bit'].map(os_bit_dict)

# %%
df['os'].unique()
# Out:
# array(['Windows', 'DOS', 'Mac'], dtype=object)

# %%
os_dict = {
    'Windows':1, 'DOS':2, 'Mac':3
}

# %%
df['os'] = df['os'].map(os_dict)

# %%
df['hdd'].unique()
# Out:
# array(['1024 GB', '0 GB', '512 GB', '2048 GB'], dtype=object)

# %%
hdd_dict = {
    '1024 GB':3, '0 GB':1, '512 GB':2, '2048 GB':4
}

# %%
df['hdd'] = df['hdd'].map(hdd_dict)

# %%
df['ssd'].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
ssd_dict = {
    '0 GB':1, '512 GB':3, '256 GB':2, '128 GB':4, '1024 GB':5, '2048 GB':6,
       '3072 GB':7
}

# %%
df['ssd'] = df['ssd'].map(ssd_dict)

# %%
df['ram_type'].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
ram_type_dict = {
    'DDR4':3, 'LPDDR4':4, 'LPDDR4X':5, 'DDR5':6, 'DDR3':1, 'LPDDR3':2
}

# %%
df['ram_type'] = df['ram_type'].map(ram_type_dict)

# %%
df.head()
# Out:
#    brand  processor_brand  processor_name  processor_gnrtn  ram_gb  ram_type  \
# 0      1                0               1                5       1         3
# 1      2                0               1                5       1         3
# 2      2                0               1                5       1         3
# 3      1                0               2                5       2         3
# 4      1                0               3                0       1         3
#
#    ssd  hdd  os  os_bit  graphic_card_gb  Touchscreen  Price
# 0    1    3   1       2                1            0  34649
# 1    1    3   1       2                1            0  38999
# 2    1    3   1       2                1            0  39999
# 3    3    1   1       1                2            0  69990
# 4    1    2   1       2                1            0  26990

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            802 non-null    int64
#  1   processor_brand  802 non-null    int64
#  2   processor_name   802 non-null    int64
#  3   processor_gnrtn  802 non-null    int64
#  4   ram_gb           802 non-null    int64
#  5   ram_type         802 non-null    int64
#  6   ssd              802 non-null    int64
#  7   hdd              802 non-null    int64
#  8   os               802 non-null    int64
#  9   os_bit           802 non-null    int64
#  10  graphic_card_gb  802 non-null    int64
#  11  Touchscreen      802 non-null    int64
#  12  Price            802 non-null    int64
# dtypes: int64(13)
# memory usage: 87.7 KB

# %%
df.head()
# Out:
#    brand  processor_brand  processor_name  processor_gnrtn  ram_gb  ram_type  \
# 0      1                0               1                5       1         3
# 1      2                0               1                5       1         3
# 2      2                0               1                5       1         3
# 3      1                0               2                5       2         3
# 4      1                0               3                0       1         3
#
#    ssd  hdd  os  os_bit  graphic_card_gb  Touchscreen  Price
# 0    1    3   1       2                1            0  34649
# 1    1    3   1       2                1            0  38999
# 2    1    3   1       2                1            0  39999
# 3    3    1   1       1                2            0  69990
# 4    1    2   1       2                1            0  26990

# %%
x = df.drop('Price',axis=1)  # independent

# %%
y = df[['Price']] # dependent

# %%
x
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                0               1                5       1
# 1        2                0               1                5       1
# 2        2                0               1                5       1
# 3        1                0               2                5       2
# 4        1                0               3                0       1
# ..     ...              ...             ...              ...     ...
# 818      1                1              11                0       1
# 819      1                1              11                0       1
# 820      1                1              11                0       1
# 821      1                1              11                0       1
# 822      2                1               4                5       2
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  Touchscreen
# 0           3    1    3   1       2                1            0
# ...

# %%
y
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [802 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((641, 12), (161, 12), (641, 1), (161, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr =LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.5698466430886298

# %%
lr.score(x_train,y_train)
# Out:
# 0.6667464855634475

# %%
pred = lr.predict(x_test)

# %%
pridiction_history={"predicted_price":pred,"actual_prive":y_test}

# %%
pred = pd.DataFrame(pred)

# %%
pd.concat([pred,y_test],axis=1)
# Out:
#                 0    Price
# 0    41322.343161      NaN
# 1    67247.698049  38999.0
# 2    60826.574138  39999.0
# 3    51038.056436      NaN
# 4    60305.464933      NaN
# ..            ...      ...
# 665           NaN  44490.0
# 214           NaN  61999.0
# 724           NaN  59999.0
# 317           NaN  70990.0
# 206           NaN  49490.0
#
# [294 rows x 2 columns]
